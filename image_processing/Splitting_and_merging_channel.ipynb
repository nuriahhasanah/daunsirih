# %% [markdown]
# <a href="https://colab.research.google.com/github/nuriahhasanah/daunsirih/blob/master/Splitting_and_merging_channel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/nuriahhasanah/daunsirih/master/WhatsApp%20Image%202021-10-15%20at%2012.27.14.jpeg --no-check-certificate
# Out:
# --2021-11-09 04:20:27--  https://raw.githubusercontent.com/nuriahhasanah/daunsirih/master/WhatsApp%20Image%202021-10-15%20at%2012.27.14.jpeg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 191927 (187K) [image/jpeg]
# Saving to: ‘WhatsApp Image 2021-10-15 at 12.27.14.jpeg’
#
# WhatsApp Image 2021 100%[===================>] 187.43K  --.-KB/s    in 0.02s
#
# 2021-11-09 04:20:27 (9.88 MB/s) - ‘WhatsApp Image 2021-10-15 at 12.27.14.jpeg’ saved [191927/191927]

# %%
# import the necessary packages
from matplotlib import pyplot as plt
import numpy as np
import argparse
import cv2

# %%
def plt_imshow(title, image):
	# convert the image frame BGR to RGB color space and display it
	image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
	plt.imshow(image)
	plt.title(title)
	plt.grid(False)
	plt.show()

# %%
# since we are using Jupyter Notebooks we can replace our argument
# parsing code with *hard coded* arguments and values
args = {
	"image": "WhatsApp Image 2021-10-15 at 12.27.14.jpeg"
}

# %%
# load the input image and grab each channel -- note how OpenCV
# represents images as NumPy arrays with channels in Blue, Green,
# Red ordering rather than Red, Green Blue
image = cv2.imread(args["image"])
(B, G, R) = cv2.split(image)

# show each channel individually
plt_imshow("Red", R)
plt_imshow("Green", G)
plt_imshow("Blue", B)

# %%
merged = cv2.merge([B, G, R])
plt_imshow("Merged", merged)

# %%
# visualize each channel in color
zeros = np.zeros(image.shape[:2], dtype="uint8")
plt_imshow("Red", cv2.merge([zeros, zeros, R]))
plt_imshow("Green", cv2.merge([zeros, G, zeros]))
plt_imshow("Blue", cv2.merge([B, zeros, zeros]))
